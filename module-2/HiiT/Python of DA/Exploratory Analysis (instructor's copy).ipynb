# %%
import pandas as pd

# %%
df = pd.read_csv('Automobile_data.csv')

# %%
df.shape
# Out:
# (61, 10)

# %%
# df.head(2)
# df.tail(2)
# df.sample(2)
pd.set_option('display.max_rows',None)

df.styl

# %%
df.head(2)
# Out:
#    index      company   body-style  wheel-base  length engine-type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
#
#   num-of-cylinders  horsepower  average-mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0

# %%
# df.dtypes

# df.info()

df.isnull().sum()  #checking for missing values on each column

df.isnull().sum().sum()  #checking for missing values on each column

df.duplicated().sum() #checking for duplicate rows in the data

df['company'].duplicated().sum() #checking for duplicate rows in the data

df['company'].unique()

df['company'].nunique()

df['company'].value_counts()

# df['company'].value_counts().plot(kind='pie',figsize=(10,7),autopct=('%1.1f%%'))

df.columns

df.index

df['company'].value_counts().plot(kind='bar',figsize=(12,5))
# Out:
# <AxesSubplot:>

# %%
# df.columns = df.columns.str.upper()

df.columns = df.columns.str.replace('-','_')

# %% [markdown]
# # Conditional Selection

# %%
== (equals to)
!= (not equals to)
> (greater)
< (less)
>= (greater than/equals to)
<= (less than/equals to)

# %%
df.head()
# Out:
#    index      company   body_style  wheel_base  length engine_type  \
# 0      0  alfa-romero  convertible        88.6   168.8        dohc
# 1      1  alfa-romero  convertible        88.6   168.8        dohc
# 2      2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3      3         audi        sedan        99.8   176.6         ohc
# 4      4         audi        sedan        99.4   176.6         ohc
#
#   num_of_cylinders  horsepower  average_mileage    price
# 0             four         111               21  13495.0
# 1             four         111               21  16500.0
# 2              six         154               19  16500.0
# 3             four         102               24  13950.0
# 4             five         115               18  17450.0

# %% [markdown]
# ## Filtering using the Query Method

# %%
#how many autos in the data have a horsepower greater than 100
df.query('horsepower>100').shape

df.query('horsepower>100').shape[0]

#what are the engine-types peculiar ot the toyota automobile
df.query('company=="toyota"')

# df.query("company=='toyota'")['price'].sum()
df.query('company=="toyota"')['engine_type'].value_counts()

df.query('company=="toyota" & horsepower>100')
# Out:
#     index company body_style  wheel_base  length engine_type num_of_cylinders  \
# 54     79  toyota      wagon       104.5   187.8        dohc              six
#
#     horsepower  average_mileage    price
# 54         156               19  15750.0

# %%
& (and)
| (or)

# %% [markdown]
# ## Filtering Using the loc method

# %%
df.loc[df['company']=='toyota']

df.loc[df['company']=='toyota']['price'].mean()
# Out:
# 8216.857142857143

# %%
df.loc[df['horsepower']>200] #locating rows with horsepower > 100

df.loc[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [index, company, body_style, wheel_base, length, engine_type, num_of_cylinders, horsepower, average_mileage, price]
# Index: []

# %% [markdown]
# ## Filtering with Wildcards

# %%
df.loc[df['company'].str.startswith('t')]

df.loc[df['company'].str.endswith('w')]

df.loc[df['company'].str.contains('ota')] #where it contains 'ota'
df.loc[df['company'].str.contains('zd')]  #where it contains 'zd'

df.loc[df['company'].str.contains('^t')] #where it begins with t
df.loc[df['company'].str.contains('^[ac]')] #where it begins with a or c

df.loc[df['company'].str.contains('^[a-c]')] #where it begins with a to c

df.loc[df['company'].str.contains('a$')] #where it ends with t
# Out:
#     index company body_style  wheel_base  length engine_type num_of_cylinders  \
# 18     27   honda      wagon        96.5   157.1         ohc             four
# 19     28   honda      sedan        96.5   175.4         ohc             four
# 20     29   honda      sedan        96.5   169.1         ohc             four
# 27     36   mazda  hatchback        93.1   159.1         ohc             four
# 28     37   mazda  hatchback        93.1   159.1         ohc             four
# 29     38   mazda  hatchback        93.1   159.1         ohc             four
# 30     39   mazda  hatchback        95.3   169.0       rotor              two
# 31     43   mazda      sedan       104.9   175.0         ohc             four
# 48     66  toyota  hatchback        95.7   158.7         ohc             four
# 49     67  toyota  hatchback        95.7   158.7         ohc             four
# 50     68  toyota  hatchback        95.7   158.7         ohc             four
# ...

# %%
df.query('company=="toyota" & company=="mazda"')
df.query('company=="toyota" or company=="mazda"')

# df.query('company=="toyota" & wheel_base>100')
# Out:
#     index company body_style  wheel_base  length engine_type num_of_cylinders  \
# 27     36   mazda  hatchback        93.1   159.1         ohc             four
# 28     37   mazda  hatchback        93.1   159.1         ohc             four
# 29     38   mazda  hatchback        93.1   159.1         ohc             four
# 30     39   mazda  hatchback        95.3   169.0       rotor              two
# 31     43   mazda      sedan       104.9   175.0         ohc             four
# 48     66  toyota  hatchback        95.7   158.7         ohc             four
# 49     67  toyota  hatchback        95.7   158.7         ohc             four
# 50     68  toyota  hatchback        95.7   158.7         ohc             four
# 51     69  toyota      wagon        95.7   169.7         ohc             four
# 52     70  toyota      wagon        95.7   169.7         ohc             four
# 53     71  toyota      wagon        95.7   169.7         ohc             four
# ...
