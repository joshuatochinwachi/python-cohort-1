# %%
import pandas as pd

# %% [markdown]
# ### importing from clipboard

# %%
db = pd.read_clipboard()

# %%
db
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# 5       5         audi        sedan        99.8   177.3         ohc
# 6       6         audi        wagon       105.8   192.7         ohc
# 7       9          bmw        sedan       101.2   176.8         ohc
# 8      10          bmw        sedan       101.2   176.8         ohc
# 9      11          bmw        sedan       101.2   176.8         ohc
# 10     13          bmw        sedan       103.5   189.0         ohc
# 11     14          bmw        sedan       103.5   193.8         ohc
# 12     15          bmw        sedan       110.0   197.0         ohc
# ...

# %% [markdown]
# ### importing from excel / csv

# %%
db1 = pd.read_csv(r"C:\Users\Jo$h\Desktop\Automobile_data.csv")    

#r stands for regular expression
#you can decide to either use 'r' or use \\ instead of \

# %%
db1
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         111               21  13495.0
# ...

# %%
db2 = pd.read_excel(r'C:\Users\Jo$h\Desktop\Academic Success.xlsx')

# %%
db2
# Out:
#    Degree Level  Age  Gender Hours_sleep          Fees  \
# 0            BA   25  Female           6  Your parents
# 1           MBA   23  Female           6           You
# 2            BA   21  Female           5           You
# 3            BA   19  Female           6           You
# 4            BA   20  Female           6  Your parents
# ..          ...  ...     ...         ...           ...
# 91           BA   23    Male           8           You
# 92           BA   25    Male           9           You
# 93           BA   26  Female           8  Your parents
# 94          MBA   27    Male           6           You
# 95           BA   22    Male           4           You
#
#    Extracurricular activities Bac_type  Bac_grade   GPA English_level  \
# 0                      Rarely       SV       12.0  3.23     Excellent
# 1                      Rarely       SE       13.0  2.40          Fair
# 2                      Rarely       SE       18.0  4.00     Excellent
# ...

# %% [markdown]
# ### importing from html

# %% [markdown]
# ###### web scraping (BeautifulSoup, Scrapy, Selenium)

# %%
#kaggle.com
#uci.com
#data.gov and others

# %%
wiki = pd.read_html('https://en.wikipedia.org/wiki/List_of_countries_by_population_(United_Nations)')[0]

# %%
wiki=wiki[['Country or territory', 'Population (1 July 2022)', 'Population (1 July 2023)']]

# %%
wiki
# Out:
#                   Country or territory  Population (1 July 2022)  \
# 0                                World                8021407192
# 1                                India                1425423212
# 2                             China[a]                1425179569
# 3                        United States                 341534046
# 4                            Indonesia                 278830529
# ..                                 ...                       ...
# 233        Montserrat (United Kingdom)                      4453
# 234  Falkland Islands (United Kingdom)                      3490
# 235              Tokelau (New Zealand)                      2290
# 236                 Niue (New Zealand)                      1821
# 237                    Vatican City[x]                       505
#
#      Population (1 July 2023)
# 0                  8091734930
# 1                  1438069596
# 2                  1422584933
# 3                   343477335
# ...

# %%
wiki.head(20)  #this shows the top 20
# Out:
#    Country or territory  Population (1 July 2022)  Population (1 July 2023)
# 0                 World                8021407192                8091734930
# 1                 India                1425423212                1438069596
# 2              China[a]                1425179569                1422584933
# 3         United States                 341534046                 343477335
# 4             Indonesia                 278830529                 281190067
# 5              Pakistan                 243700667                 247504495
# 6               Nigeria                 223150896                 227882945
# 7                Brazil                 210306415                 211140729
# 8            Bangladesh                 169384897                 171466990
# 9                Russia                 145579899                 145440500
# 10               Mexico                 128613117                 129739759
# ...

# %%
wiki.style.background_gradient()
# Out:
# <style type="text/css">
# #T_f055e_row0_col1, #T_f055e_row0_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_f055e_row1_col1, #T_f055e_row1_col2, #T_f055e_row2_col1, #T_f055e_row2_col2 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_f055e_row3_col1, #T_f055e_row3_col2 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_f055e_row4_col1, #T_f055e_row4_col2 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_f055e_row5_col1, #T_f055e_row5_col2, #T_f055e_row6_col1, #T_f055e_row6_col2 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_f055e_row7_col1, #T_f055e_row7_col2 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_f055e_row8_col1, #T_f055e_row8_col2 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# ...

# %%
wiki.style.bar()
# Out:
# <style type="text/css">
# #T_028aa_row0_col1, #T_028aa_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 100.0%, transparent 100.0%);
# }
# #T_028aa_row1_col1, #T_028aa_row1_col2, #T_028aa_row2_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 17.8%, transparent 17.8%);
# }
# #T_028aa_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 17.6%, transparent 17.6%);
# }
# #T_028aa_row3_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 4.3%, transparent 4.3%);
# }
# #T_028aa_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 4.2%, transparent 4.2%);
# }
# #T_028aa_row4_col1, #T_028aa_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 3.5%, transparent 3.5%);
# }
# #T_028aa_row5_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #d65f5f 3.0%, transparent 3.0%);
# }
# #T_028aa_row5_col2 {
#   width: 10em;
# ...

# %%
wiki.drop(index=0, inplace=True)
# Out:
# C:\Users\Jo$h\AppData\Local\Temp\ipykernel_7852\3127371800.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wiki.drop(index=0, inplace=True)

# %%
wiki
# Out:
#                   Country or territory  Population (1 July 2022)  \
# 1                                India                1425423212
# 2                             China[a]                1425179569
# 3                        United States                 341534046
# 4                            Indonesia                 278830529
# 5                             Pakistan                 243700667
# ..                                 ...                       ...
# 233        Montserrat (United Kingdom)                      4453
# 234  Falkland Islands (United Kingdom)                      3490
# 235              Tokelau (New Zealand)                      2290
# 236                 Niue (New Zealand)                      1821
# 237                    Vatican City[x]                       505
#
#      Population (1 July 2023)
# 1                  1438069596
# 2                  1422584933
# 3                   343477335
# 4                   281190067
# ...

# %%
wiki.to_excel('samplewiki.xlsx')
