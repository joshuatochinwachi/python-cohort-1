# %%
import pandas as pd

# %%
df = pd.read_csv('Automobile_data.csv')

# %%
df
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         111               21  13495.0
# ...

# %%
df[['company', 'horsepower', 'length']].groupby('company').agg(['sum','mean'])

df[['company', 'horsepower', 'length']].groupby('company').agg(['sum','mean']).plot(kind='bar')
# Out:
# <Axes: xlabel='company'>

# %%
df[['company', 'horsepower']].groupby('company').sum().plot(kind='bar')
df[['company', 'horsepower']].groupby('company').sum().plot(kind='bar', figsize=(12,5))
# Out:
# <Axes: xlabel='company'>

# %%
df[['company','horsepower']].groupby('company').sum().plot(kind='bar',
                                                           figsize=(12,5),
                                                          color='yellow',
                                                          grid=True,
                                                          title = 'AUTO LENGTH',
                                                          xlabel = 'COMPANY',
                                                          ylabel = 'LENGTH')
# Out:
# <Axes: title={'center': 'AUTO LENGTH'}, xlabel='COMPANY', ylabel='LENGTH'>

# %%
import matplotlib.pyplot as plt

# or 
# from matplotlib import pyplot as plt

# %%
import seaborn as sns

# %% [markdown]
# ### Demonstration

# %%
x = df['company']
y = df['length']

# %% [markdown]
# ###### matplotlib

# %%
plt.bar(x,y)
# Out:
# <BarContainer object of 61 artists>

# %%
plt.barh(x,y)
# Out:
# <BarContainer object of 61 artists>

# %%
plt.scatter(x,y)

# %%
plt.stackplot(x,y)

# %%
plt.pie(y)
# Out:
# ([<matplotlib.patches.Wedge at 0x155e7832810>,
# ...
#  [Text(1.0986130194913224, 0.05522167512996621, ''),
#   Text(1.0875381525826235, 0.16510834829642765, ''),
#   Text(1.0653046137394016, 0.27409137152698704, ''),
#   Text(1.0312935999955681, 0.38266631757731384, ''),
#   Text(0.9854652747391793, 0.48873120657804736, ''),
#   Text(0.9286414803968087, 0.5895973209627261, ''),
#   Text(0.8582452795551971, 0.6880516260581191, ''),
#   Text(0.7775744833021276, 0.7780603594306996, ''),
#   Text(0.6915697875111536, 0.8554128997167263, ''),
#   Text(0.5979176883266699, 0.9233062536266563, ''),
#   Text(0.49408969444789785, 0.9827895877757269, ''),
#   Text(0.3791970406834285, 1.032574260930869, ''),
#   Text(0.2568457213124853, 1.0695935094434097, ''),
#   Text(0.1481339299936825, 1.0899799717355483, ''),
#   Text(0.05136446229630585, 1.0988001146764645, ''),
#   Text(-0.051592992997560205, 1.0987894079729537, ''),
#   Text(-0.154552131517189, 1.0890884439032, ''),
# ...

# %%
plt.pie(y, labels = y)
# Out:
# ([<matplotlib.patches.Wedge at 0x155e7860610>,
# ...
#  [Text(1.0986130194913224, 0.05522167512996621, '168.8'),
#   Text(1.0875381525826235, 0.16510834829642765, '168.8'),
#   Text(1.0653046137394016, 0.27409137152698704, '171.2'),
#   Text(1.0312935999955681, 0.38266631757731384, '176.6'),
#   Text(0.9854652747391793, 0.48873120657804736, '176.6'),
#   Text(0.9286414803968087, 0.5895973209627261, '177.3'),
#   Text(0.8582452795551971, 0.6880516260581191, '192.7'),
#   Text(0.7775744833021276, 0.7780603594306996, '176.8'),
#   Text(0.6915697875111536, 0.8554128997167263, '176.8'),
#   Text(0.5979176883266699, 0.9233062536266563, '176.8'),
#   Text(0.49408969444789785, 0.9827895877757269, '189.0'),
#   Text(0.3791970406834285, 1.032574260930869, '193.8'),
#   Text(0.2568457213124853, 1.0695935094434097, '197.0'),
#   Text(0.1481339299936825, 1.0899799717355483, '141.1'),
#   Text(0.05136446229630585, 1.0988001146764645, '155.9'),
# ...

# %%
plt.pie(y, labels = y);

# %%
plt.pie(y, labels = y)
debug = True

# %% [markdown]
# #### NB: Using Debug = True or ending the code with ; prevents some additional stuff

# %% [markdown]
# ###### seaborn

# %%
sns.barplot(data = df,x = 'company', y='length')
# Out:
# <Axes: xlabel='company', ylabel='length'>

# %%
sns.relplot(data = df,x = 'company', y='length')

# %%
sns.relplot(data = df,x = 'company', y='length',kind='line')

# %% [markdown]
# ### barplot / line plot / scatter plot

# %% [markdown]
# ### xlabel, ylabel and title

# %%
plt.bar(df['company'],df['horsepower'])
# Out:
# <BarContainer object of 61 artists>

# %%
plt.plot(df['company'],df['horsepower'])

# %%
plt.bar(df['company'],df['horsepower'])
plt.title('TEST SAMPLE', size=20)
# Out:
# Text(0.5, 1.0, 'TEST SAMPLE')

# %%
plt.bar(df['company'],df['horsepower'])
plt.title('TEST SAMPLE', size=20)
plt.xlabel('COMPANY NAMES', size=15)
# Out:
# Text(0.5, 0, 'COMPANY NAMES')

# %%
plt.bar(df['company'],df['horsepower'])
plt.title('TEST SAMPLE', size=20)
plt.xlabel('COMPANY NAMES', size=15)
plt.ylabel('HORSEPOWER')
# Out:
# Text(0, 0.5, 'HORSEPOWER')

# %%
plt.bar(df['company'],df['horsepower'],color='red')
plt.title('TEST SAMPLE', size=20)
plt.xlabel('COMPANY NAMES', size=15)
plt.ylabel('HORSEPOWER')
# Out:
# Text(0, 0.5, 'HORSEPOWER')

# %% [markdown]
# ### xticks, yticks and figure

# %%
plt.bar(df['company'],df['horsepower'],color='red')
plt.title('TEST SAMPLE', size=20)
plt.xlabel('COMPANY NAMES', size=15)
plt.ylabel('HORSEPOWER')
plt.xticks(rotation=90);

# %%
plt.bar(df['company'],df['horsepower'],color='red')
plt.title('TEST SAMPLE', size=20)
plt.xlabel('COMPANY NAMES', size=15)
plt.ylabel('HORSEPOWER')
plt.xticks(rotation=90)
plt.yticks(rotation=45);

#u can also use debug = True to replace the ;

# %%
plt.figure(figsize=(12,8))
plt.bar(df['company'],df['horsepower'],color='red')
plt.title('TEST SAMPLE', size=20)
plt.xlabel('COMPANY NAMES', size=15)
plt.ylabel('HORSEPOWER')
plt.xticks(rotation=90)
plt.yticks(rotation=45);

# %% [markdown]
# ### Legends and labels

# %%
plt.plot(df['company'],df['horsepower'],color='red')

# %%
plt.plot(df['company'],df['horsepower'],color='red')
plt.plot(df['company'],df['length'],color='blue')

# %%
plt.figure(figsize=(12,5))
plt.plot(df['company'],df['horsepower'],color='red',label='HP')
plt.plot(df['company'],df['length'],color='blue',label='COMPANY')
plt.legend()

#if u want the labels to appear, you must put a legend syntax

# %%
plt.figure(figsize=(12,5))
plt.plot(df['company'],df['horsepower'],color='red',label='HP')
plt.scatter(df['company'],df['length'],color='blue',label='COMPANY')
plt.legend(loc='upper left')

# %%
plt.figure(figsize=(12,5))
plt.plot(df['company'],df['horsepower'],color='red',label='HP')
plt.scatter(df['company'],df['length'],color='blue',label='COMPANY')
plt.legend(loc='best')

# %%
plt.figure(figsize=(12,5))
plt.bar(df['company'],df['horsepower'],color ='red',label = 'HP',align='edge',width = 0.4)
plt.bar(df['company'],df['length'],color ='blue',label = 'COmPANY',align='edge',width = -0.4)
plt.legend(loc='upper left')

# %% [markdown]
# ### plot a bar chart showing the numbers of all non-toyota autos in the data

# %%
df.query('company != "toyota" ')
df.query('company != "toyota" ').shape
# Out:
# (54, 10)

# %%
df.query('company != "toyota" ')[['company', 'price']].groupby('company').count()
# Out:
#                price
# company
# alfa-romero        3
# audi               4
# bmw                6
# chevrolet          3
# dodge              2
# honda              3
# isuzu              1
# jaguar             3
# mazda              5
# mercedes-benz      4
# mitsubishi         4
# nissan             5
# porsche            2
# volkswagen         4
# volvo              2

# %%
df.query('company != "toyota" ')[['company', 'price']].groupby('company').count().plot(kind='bar')
# Out:
# <Axes: xlabel='company'>

# %%
df.query('company != "toyota" ')[['company', 
                                  'price']].groupby('company').count().plot(kind='pie',y='price')
# Out:
# <Axes: ylabel='price'>

# %%
df.query('company != "toyota" ')[['company', 
                                  'price']].groupby('company').count().plot(kind='pie',y='price')
plt.title('NUMBERS ON NON TOYOTA AUTOS')
# Out:
# Text(0.5, 1.0, 'NUMBERS ON NON TOYOTA AUTOS')

# %%
df.query('company != "toyota" ')[['company', 
                                  'price']].groupby('company').count().plot(kind='pie',y='price',
                                                                           legend = False,
                                                                           figsize = (12, 8))
plt.title('NUMBERS ON NON TOYOTA AUTOS')
# Out:
# Text(0.5, 1.0, 'NUMBERS ON NON TOYOTA AUTOS')

# %%
df[['company','horsepower']].groupby('company').sum().plot(kind='bar', y = 'horsepower')


#the group by made the company column the index and the x axis automatically, so in this case, you can't set the x axis yourself
# Out:
# <Axes: xlabel='company'>

# %%
df[['company','wheel-base','horsepower']].groupby('company').sum()
# Out:
#                wheel-base  horsepower
# company
# alfa-romero         271.7         376
# audi                404.8         437
# bmw                 620.6         869
# chevrolet           277.4         188
# dodge               187.4         136
# honda               289.5         277
# isuzu               283.3         218
# jaguar              328.0         614
# mazda               479.5         377
# mercedes-benz       452.9         614
# mitsubishi          380.0         312
# nissan              478.4         414
# porsche             277.4         702
# toyota              678.7         528
# volkswagen          389.2         289
# volvo               208.6         228

# %%
df[['company','wheel-base','horsepower']].groupby('company').sum().plot(kind='line')
# Out:
# <Axes: xlabel='company'>

# %%
df[['company','wheel-base','horsepower']].groupby('company').sum().plot(kind='line')
plt.grid()

# %%
df[['company','wheel-base','horsepower']].groupby('company').sum().plot(kind='line')
plt.grid(color='green')

# %%
df[['company','wheel-base','horsepower']].groupby('company').sum().plot(kind='line',figsize=(12,5))
plt.grid(color='green')

# %%
df[['company','wheel-base','horsepower']].groupby('company').sum().plot(kind='line',figsize=(12,5))
plt.grid(color='green')
plt.legend(loc='lower left')

# %%
df[['company','wheel-base','horsepower']].groupby('company').sum().plot(kind='bar',figsize=(12,5))
plt.grid(color='green')
plt.legend(loc='lower left')

# %%
df[['company','wheel-base','horsepower']].groupby('company').sum().plot(kind='box',figsize=(12,5))
plt.grid(color='green')
plt.legend(loc='lower left')
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
df[['company','wheel-base','horsepower']].groupby('company').sum().plot(kind='area',figsize=(12,5))
plt.grid(color='green')
plt.legend(loc='lower left')

# %%
df[['company','wheel-base','horsepower']].groupby('company').sum()
# Out:
#                wheel-base  horsepower
# company
# alfa-romero         271.7         376
# audi                404.8         437
# bmw                 620.6         869
# chevrolet           277.4         188
# dodge               187.4         136
# honda               289.5         277
# isuzu               283.3         218
# jaguar              328.0         614
# mazda               479.5         377
# mercedes-benz       452.9         614
# mitsubishi          380.0         312
# nissan              478.4         414
# porsche             277.4         702
# toyota              678.7         528
# volkswagen          389.2         289
# volvo               208.6         228

# %%
df[['company','wheel-base','horsepower']].groupby('company').sum().reset_index()
# Out:
#           company  wheel-base  horsepower
# 0     alfa-romero       271.7         376
# 1            audi       404.8         437
# 2             bmw       620.6         869
# 3       chevrolet       277.4         188
# 4           dodge       187.4         136
# 5           honda       289.5         277
# 6           isuzu       283.3         218
# 7          jaguar       328.0         614
# 8           mazda       479.5         377
# 9   mercedes-benz       452.9         614
# 10     mitsubishi       380.0         312
# 11         nissan       478.4         414
# 12        porsche       277.4         702
# 13         toyota       678.7         528
# 14     volkswagen       389.2         289
# 15          volvo       208.6         228

# %%
df2 = df[['company','wheel-base','horsepower']].groupby('company').sum().reset_index()

# %%
plt.pie(df2['horsepower']);

# %%
plt.pie(df2['horsepower'],labels=df2['company']);

# %%
plt.pie(df2['horsepower'],labels=df2['company'],wedgeprops={'width':0.5});

# %%
plt.figure(figsize=(12,6))
plt.pie(df2['horsepower'],labels=df2['company'],wedgeprops={'width':0.5});

# %%
plt.figure(figsize=(12,6))
plt.pie(df2['horsepower'],labels=df2['company'],
        wedgeprops={'width':0.5},
       textprops = {'size':20, 'color':'blue'});

# %%
plt.figure(figsize=(15,10))
plt.pie(df2['horsepower'],labels=df2['company'],
        wedgeprops={'width':1},
       textprops = {'size':20, 'color':'black'},
       autopct = '%1.1f%%');

# %% [markdown]
# ## Using Numpy (briefly)

# %%
import numpy as np

# %%
np.random.randint(4,20)
# Out:
# 11

# %% [markdown]
# ## Using Seaborn

# %%
import seaborn as sns

# %%
sns.get_dataset_names()

#u can work with these data sets and even build a portfolio
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic',
#  'anagrams',
#  'anagrams',
#  'anscombe',
#  'anscombe',
#  'attention',
#  'attention',
#  'brain_networks',
#  'brain_networks',
#  'car_crashes',
#  'car_crashes',
#  'diamonds',
#  'diamonds',
#  'dots',
#  'dots',
#  'dowjones',
#  'dowjones',
#  'exercise',
#  'exercise',
#  'flights',
#  'flights',
#  'fmri',
#  'fmri',
#  'geyser',
#  'geyser',
#  'glue',
#  'glue',
#  'healthexp',
#  'healthexp',
#  'iris',
#  'iris',
#  'mpg',
#  'mpg',
#  'penguins',
#  'penguins',
#  'planets',
#  'planets',
#  'seaice',
#  'seaice',
#  'taxis',
#  'taxis',
#  'tips',
#  'tips',
#  'titanic',
#  'titanic',
#  'anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
# ...

# %%
db = sns.load_dataset('titanic')

# %%
# sns.barplot(x,y)
# sns.relplot(x,y,kind='line')
# sns.boxplot(x,y)

# sns.violinplot(x,y)
# plt.xticks(rotation=90);

# sns.dogplot(x,y)
sns.pairplot(df)

# %%
sns.countplot(data = df, x = 'company')


# like a value count
# Out:
# <Axes: xlabel='company', ylabel='count'>

# %%
sns.countplot(data = df, x = 'company', palette = 'plasma')
plt.xticks(rotation=90);

# %% [markdown]
# ##### Heat map (typically used in ML)

# %%
df.corr()
# Out:
# C:\Users\Jo$h\AppData\Local\Temp\ipykernel_15684\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                     index  wheel-base    length  horsepower  average-mileage  \
# index            1.000000    0.013401  0.004828   -0.093809         0.176037
# wheel-base       0.013401    1.000000  0.878381    0.463421        -0.547325
# length           0.004828    0.878381  1.000000    0.668555        -0.788429
# horsepower      -0.093809    0.463421  0.668555    1.000000        -0.808804
# average-mileage  0.176037   -0.547325 -0.788429   -0.808804         1.000000
# price           -0.197470    0.663085  0.788465    0.901707        -0.770217
#
#                     price
# index           -0.197470
# wheel-base       0.663085
# length           0.788465
# horsepower       0.901707
# ...

# %% [markdown]
# ###### ML is using data of old to predict the future

# %%
df
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         111               21  13495.0
# ...

# %% [markdown]
# ###### price prediction model is a good project to work on

# %%
df.corr()
# Out:
# C:\Users\Jo$h\AppData\Local\Temp\ipykernel_15684\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                     index  wheel-base    length  horsepower  average-mileage  \
# index            1.000000    0.013401  0.004828   -0.093809         0.176037
# wheel-base       0.013401    1.000000  0.878381    0.463421        -0.547325
# length           0.004828    0.878381  1.000000    0.668555        -0.788429
# horsepower      -0.093809    0.463421  0.668555    1.000000        -0.808804
# average-mileage  0.176037   -0.547325 -0.788429   -0.808804         1.000000
# price           -0.197470    0.663085  0.788465    0.901707        -0.770217
#
#                     price
# index           -0.197470
# wheel-base       0.663085
# length           0.788465
# horsepower       0.901707
# ...

# %%
# research more on multicolinearity test

# %%
# heatmap proper

# %%
sns.heatmap(df.corr(),annot=True)
plt.savefig('heat_test.pdf')
# Out:
# C:\Users\Jo$h\AppData\Local\Temp\ipykernel_15684\631673070.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)

# %%
# streamlit, ipywidgets are libraries for dashboard
