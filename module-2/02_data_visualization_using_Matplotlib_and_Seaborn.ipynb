# %% [markdown]
# ### Install/Import Matplotlib

# %%
# !pip install matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Basic Setup

# %%
student = ['Daniel', 'Alfred', 'Amah', 'Divine', 'Ruth', 'George']
scores = [80, 90, 70, 60, 85, 74]

# %% [markdown]
# ### Line Plot

# %%
plt.plot(student, scores, color = 'blue')

plt.title('Student Test Score')
plt.xlabel('Student Name')
plt.ylabel('Scores')
plt.show()

# %% [markdown]
# ### Scatter Plot

# %%
plt.scatter(student, scores, color = 'red')

plt.title('Student Test Score')
plt.xlabel('Student Name')
plt.ylabel('Scores')
plt.show()

# %% [markdown]
# ### Bar Plot

# %%
plt.bar(student, scores, color = 'green')

plt.title('Student Test Score')
plt.xlabel('Student Name')
plt.ylabel('Scores')
plt.show()

# %% [markdown]
# ### Histogram

# %%
plt.hist(scores, color = 'purple')

plt.title('Student Test Score')
plt.ylabel('Scores')
plt.tight_layout()
plt.show()


# shows scores in ranges

# %%
plt.figure(figsize=(10,3))

plt.bar(student, scores, color = 'green')

plt.title('Student Test Score')
plt.xlabel('Student Name')
plt.ylabel('Scores')
plt.show()

# %% [markdown]
# ## Seaborn
#
# Seaborn is a super easy tool in Python that helps you draw pretty pictures (called plots) of your data. It’s like a magic crayon box built on top of Matplotlib, making graphs look nice and simple to create for beginners!
#
# **Why Use It?**
# It turns numbers into cool, colorful pictures so you can see patterns fast.

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
#      ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#      - -------------------------------------- 10.2/294.9 kB ? eta -:--:--
#      - -------------------------------------- 10.2/294.9 kB ? eta -:--:--
#      - -------------------------------------- 10.2/294.9 kB ? eta -:--:--
#      --- --------------------------------- 30.7/294.9 kB 163.8 kB/s eta 0:00:02
#      --- --------------------------------- 30.7/294.9 kB 163.8 kB/s eta 0:00:02
#      --- --------------------------------- 30.7/294.9 kB 163.8 kB/s eta 0:00:02
#      ----- ------------------------------- 41.0/294.9 kB 131.3 kB/s eta 0:00:02
#      ------- ----------------------------- 61.4/294.9 kB 193.2 kB/s eta 0:00:02
#      ----------- ------------------------- 92.2/294.9 kB 249.8 kB/s eta 0:00:01
#      ----------- ------------------------- 92.2/294.9 kB 249.8 kB/s eta 0:00:01
#      ------------- ---------------------- 112.6/294.9 kB 273.1 kB/s eta 0:00:01
#      -------------- --------------------- 122.9/294.9 kB 267.6 kB/s eta 0:00:01
#      ----------------- ------------------ 143.4/294.9 kB 284.4 kB/s eta 0:00:01
#      ------------------------ ----------- 204.8/294.9 kB 389.1 kB/s eta 0:00:01
#      ----------------------------- ------ 245.8/294.9 kB 443.5 kB/s eta 0:00:01
#      ------------------------------- ---- 256.0/294.9 kB 425.2 kB/s eta 0:00:01
#      --------------------------------- -- 276.5/294.9 kB 426.0 kB/s eta 0:00:01
#      ------------------------------------ 294.9/294.9 kB 434.0 kB/s eta 0:00:00
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\jo$h\desktop\visual studio code\python-tutorial-cohort-1\pythonz\lib\site-packages (from seaborn) (2.3.2)
# Requirement already satisfied: pandas>=1.2 in c:\users\jo$h\desktop\visual studio code\python-tutorial-cohort-1\pythonz\lib\site-packages (from seaborn) (2.3.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\jo$h\desktop\visual studio code\python-tutorial-cohort-1\pythonz\lib\site-packages (from seaborn) (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jo$h\desktop\visual studio code\python-tutorial-cohort-1\pythonz\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\jo$h\desktop\visual studio code\python-tutorial-cohort-1\pythonz\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jo$h\desktop\visual studio code\python-tutorial-cohort-1\pythonz\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\jo$h\desktop\visual studio code\python-tutorial-cohort-1\pythonz\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\jo$h\desktop\visual studio code\python-tutorial-cohort-1\pythonz\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\jo$h\desktop\visual studio code\python-tutorial-cohort-1\pythonz\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\jo$h\desktop\visual studio code\python-tutorial-cohort-1\pythonz\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jo$h\desktop\visual studio code\python-tutorial-cohort-1\pythonz\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jo$h\desktop\visual studio code\python-tutorial-cohort-1\pythonz\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jo$h\desktop\visual studio code\python-tutorial-cohort-1\pythonz\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\jo$h\desktop\visual studio code\python-tutorial-cohort-1\pythonz\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.13.2
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip freeze > requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
import pandas as pd

# %% [markdown]
# ### Basic setup

# %%
student = ['Daniel', 'Alfred', 'Amah', 'Divine', 'Ruth', 'George']
scores = [80, 90, 70, 60, 85, 74]

data = pd.DataFrame({'Student' : student, 'Scores': scores})
print(data)
# Out:
#   Student  Scores
# 0  Daniel      80
# 1  Alfred      90
# 2    Amah      70
# 3  Divine      60
# 4    Ruth      85
# 5  George      74

# %% [markdown]
# ### Line plot

# %%
sns.lineplot(x='Student', y='Scores', data=data, color='blue')
plt.title('Student Test Scores')
plt.show()

# %% [markdown]
# ### Scatter plot

# %%
sns.scatterplot(x='Student', y='Scores', data = data, color = 'red')

plt.title('Student test scores')
plt.show()

# %% [markdown]
# ### Bar plot

# %%
sns.barplot(x='Student', y='Scores', data=data, color = 'green')

plt.title('Student Test Score')
plt.show()

# %% [markdown]
# ### Histogram

# %%
sns.histplot(data=data, x='Scores', color = 'purple')

plt.title('How scores pile up')
plt.show()

# if u save as .png, it'll have a transparent background that you can add to any background for better customizations

# %% [markdown]
# `plotly can allow u do 3D charts` ---- this for interactive visualisation
#
# `from mpl_toolkits.mplot3d import Axes3D` --- this is the one that works when you install matplotbib

# %% [markdown]
# ## Visualizing Web3 Token Transfer Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('C:\Users\Jo$h\Desktop\Visual Studio Code\python-tutorial-cohort-1\module-2\web3_token_transfers.csv')

# %%
# Kernel Density Estimate

# %%
plt.figure(figsize=(10, 6))

sns.histplot(df['amount'], bins=50, kde=True, color='skyblue')
plt.title("Distribution of Token Transfer Amounts")
plt.xlabel('Amount')
plt.ylabel('Frequency')
plt.xlim(0, 3000)
plt.show()

# %% [markdown]
# ### Daily Total transfer
