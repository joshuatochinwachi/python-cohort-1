# %% [markdown]
# # Building Streamlit App

# %% [markdown]
# Streamlit is a python library that helps turn scripts (not notebook) into web applications.

# %% [markdown]
# import notebook to script --- allows you to convert a notebook to py script

# %%
# ! pip install streamlit

import streamlit as st
