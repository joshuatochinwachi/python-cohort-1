# %%
import pandas as pd

# %%
df = pd.read_excel('Dirtydata.xlsx')

# %%
df
# Out:
#     CustomerID First_name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 1         1002       Abed        Nadir  123/643/9775
# 2         1003     Walter       /White   709/909/901
# 3         1004     Dwayne      Shurlle  123-543-2345
# 4         1005       John         Snow  876|678|3469
# 5         1006        Ron      Swanson  304-762-2467
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter    ...Parker  123-545-5421
# 10        1011      Sammy       George           NaN
# 11        1012      Harry       Potter   706#695#039
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie      Houston  876|678|3469
# 14        1015       Toby  Richardson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017    Michael        Scott  123/643/9775
# ...

# %%
df.dtypes
# Out:
# CustomerID            int64
# First_name           object
# Last_Name            object
# Phone_Number         object
# Address              object
# Paying Customer      object
# Do_Not_Contact       object
# Not_Useful_Column      bool
# dtype: object

# %%
df.style.highlight_null()
# Out:
# <style type="text/css">
# #T_b953d_row2_col6, #T_b953d_row6_col3, #T_b953d_row8_col2, #T_b953d_row8_col6, #T_b953d_row10_col3, #T_b953d_row11_col6, #T_b953d_row17_col6 {
#   background-color: red;
# }
# </style>
# <table id="T_b953d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b953d_level0_col0" class="col_heading level0 col0" >CustomerID</th>
#       <th id="T_b953d_level0_col1" class="col_heading level0 col1" >First_name</th>
#       <th id="T_b953d_level0_col2" class="col_heading level0 col2" >Last_Name</th>
#       <th id="T_b953d_level0_col3" class="col_heading level0 col3" >Phone_Number</th>
#       <th id="T_b953d_level0_col4" class="col_heading level0 col4" >Address</th>
#       <th id="T_b953d_level0_col5" class="col_heading level0 col5" >Paying Customer</th>
#       <th id="T_b953d_level0_col6" class="col_heading level0 col6" >Do_Not_Contact</th>
# ...

# %%
df.isna().sum()
df.isnull().sum()

#can also be plotted as well

df.isna().sum().plot(kind='barh')
df.isna().sum().plot(kind='pie')
# Out:
# <Axes: >

# %% [markdown]
# ### checking for duplicate rows

# %%
df.duplicated().sum()   #checking on rows that are exactly duplicated
# Out:
# 1

# %%
df['Last_Name'].duplicated().sum()
# Out:
# 1

# %% [markdown]
# ### showing the duplicate rows

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20     True
# dtype: bool

# %%
df.loc[df.duplicated()]
# Out:
#     CustomerID First_name  Last_Name  Phone_Number  \
# 20        1020     Anakin  Skywalker  876|678|3469
#
#                         Address Paying Customer Do_Not_Contact  \
# 20  910 Tatooine Road, Tatooine             Yes              N
#
#     Not_Useful_Column
# 20               True

# %% [markdown]
# ### drop duplicates

# %%
df.shape
# Out:
# (21, 8)

# %%
df.drop_duplicates(inplace = True)

# %%
df.shape
# Out:
# (20, 8)

# %%
#drop in temporary, pop is permanent

# %%
df['Paying Customer']
# Out:
# 0     Yes
# 1      No
# 2       N
# 3     Yes
# 4       Y
# 5     Yes
# 6      No
# 7       N
# 8     Yes
# 9     Yes
# 10    Yes
# 11      Y
# 12    Yes
# 13    Yes
# 14      Y
# 15     No
# 16    Yes
# 17      Y
# 18    N/a
# 19    Yes
# Name: Paying Customer, dtype: object

# %%
df['Paying Customer'].unique()
df['Paying Customer'].nunique()
# Out:
# 5

# %% [markdown]
# ### dropping columns

# %%
#dropping 1 column
#for more columns, use a list

# %%
df.drop(columns = 'Not_Useful_Column', inplace = True)

# %% [markdown]
# ### droping index(es)

# %%
df.drop(index = 1) #dropping 1 row
df.drop(index = [1,4,5])  #dropping more than 1
# Out:
#     CustomerID First_name    Last_Name  Phone_Number  \
# 0         1001      Frodo      Baggins  123-545-5421
# 2         1003     Walter       /White   709/909/901
# 3         1004     Dwayne      Shurlle  123-543-2345
# 6         1007       Jeff       Winger           NaN
# 7         1008   Sherlock       Holmes  876|678|3469
# 8         1009    Gandalf          NaN           N/a
# 9         1010      Peter    ...Parker  123-545-5421
# 10        1011      Sammy       George           NaN
# 11        1012      Harry       Potter   706#695#039
# 12        1013        Don       Draper  123-543-2345
# 13        1014     Leslie      Houston  876|678|3469
# 14        1015       Toby  Richardson_  304-762-2467
# 15        1016        Ron      Weasley  123-545-5421
# 16        1017    Michael        Scott  123/643/9775
# 17        1018      Clark         Kent   709/909/901
# 18        1019      Creed       Braton           N/a
# 19        1020     Anakin    Skywalker  876|678|3469
#
# ...

# %%
# in a more realistist case, drop based on a condition

# %% [markdown]
# ###### removing everyone from the data whose first name begins with S

# %%
df['First_name'].str[0]
df['First_name'].str[0:3]
# Out:
# 0     Fro
# 1     Abe
# 2     Wal
# 3     Dwa
# 4     Joh
# 5     Ron
# 6     Jef
# 7     She
# 8     Gan
# 9     Pet
# 10    Sam
# 11    Har
# 12    Don
# 13    Les
# 14    Tob
# 15    Ron
# 16    Mic
# 17    Cla
# 18    Cre
# 19    Ana
# Name: First_name, dtype: object

# %%
df['First_name'].str[0] == 'S'

df.loc[df['First_name'].str[0] == 'S']
# Out:
#     CustomerID First_name Last_Name  Phone_Number                Address  \
# 7         1008   Sherlock    Holmes  876|678|3469          98 Clue Drive
# 10        1011      Sammy    George           NaN  612 Shire Lane, Shire
#
#    Paying Customer Do_Not_Contact
# 7                N             No
# 10             Yes             No

# %%
df.loc[df['First_name'].str[0] == 'S'].index
# Out:
# Int64Index([7, 10], dtype='int64')

# %%
df.drop(index= df.loc[df['First_name'].str[0] == 'S'].index)
df.drop(index= df.loc[df['First_name'].str[0] == 'S'].index).shape
# Out:
# (18, 7)

# %%
# second way

# %%
df.loc[df['First_name'].str.contains('^S')].index
# Out:
# Int64Index([7, 10], dtype='int64')

# %%
df['First_name'] = df['First_name'].str.upper()

# %%
df
# Out:
#     CustomerID First_name    Last_Name  Phone_Number  \
# 0         1001      FRODO      Baggins  123-545-5421
# 1         1002       ABED        Nadir  123/643/9775
# 2         1003     WALTER       /White   709/909/901
# 3         1004     DWAYNE      Shurlle  123-543-2345
# 4         1005       JOHN         Snow  876|678|3469
# 5         1006        RON      Swanson  304-762-2467
# 6         1007       JEFF       Winger           NaN
# 7         1008   SHERLOCK       Holmes  876|678|3469
# 8         1009    GANDALF          NaN           N/a
# 9         1010      PETER    ...Parker  123-545-5421
# 10        1011      SAMMY       George           NaN
# 11        1012      HARRY       Potter   706#695#039
# 12        1013        DON       Draper  123-543-2345
# 13        1014     LESLIE      Houston  876|678|3469
# 14        1015       TOBY  Richardson_  304-762-2467
# 15        1016        RON      Weasley  123-545-5421
# 16        1017    MICHAEL        Scott  123/643/9775
# ...

# %% [markdown]
# ### Lstrip, Rstrip and Strip

# %%
df['Last_Name']
# Out:
# 0         Baggins
# 1           Nadir
# 2          /White
# 3         Shurlle
# 4            Snow
# 5         Swanson
# 6          Winger
# 7          Holmes
# 8             NaN
# 9       ...Parker
# 10         George
# 11         Potter
# 12         Draper
# 13        Houston
# 14    Richardson_
# 15        Weasley
# 16          Scott
# 17           Kent
# 18         Braton
# 19      Skywalker
# Name: Last_Name, dtype: object

# %%
df['Last_Name'].str.lstrip('/.')  #removing the / and .
# Out:
# 0         Baggins
# 1           Nadir
# 2           White
# 3         Shurlle
# 4            Snow
# 5         Swanson
# 6          Winger
# 7          Holmes
# 8             NaN
# 9          Parker
# 10         George
# 11         Potter
# 12         Draper
# 13        Houston
# 14    Richardson_
# 15        Weasley
# 16          Scott
# 17           Kent
# 18         Braton
# 19      Skywalker
# Name: Last_Name, dtype: object

# %%
df['Last_Name'].str.rstrip('_')
# Out:
# 0        Baggins
# 1          Nadir
# 2         /White
# 3        Shurlle
# 4           Snow
# 5        Swanson
# 6         Winger
# 7         Holmes
# 8            NaN
# 9      ...Parker
# 10        George
# 11        Potter
# 12        Draper
# 13       Houston
# 14    Richardson
# 15       Weasley
# 16         Scott
# 17          Kent
# 18        Braton
# 19     Skywalker
# Name: Last_Name, dtype: object

# %%
df['Last_Name'].str.strip('/._')  #removing the /   .   and _
# Out:
# 0        Baggins
# 1          Nadir
# 2          White
# 3        Shurlle
# 4           Snow
# 5        Swanson
# 6         Winger
# 7         Holmes
# 8            NaN
# 9         Parker
# 10        George
# 11        Potter
# 12        Draper
# 13       Houston
# 14    Richardson
# 15       Weasley
# 16         Scott
# 17          Kent
# 18        Braton
# 19     Skywalker
# Name: Last_Name, dtype: object

# %%
df['Last_Name'].str.strip('/._').fillna('Unknown')
# Out:
# 0        Baggins
# 1          Nadir
# 2          White
# 3        Shurlle
# 4           Snow
# 5        Swanson
# 6         Winger
# 7         Holmes
# 8        Unknown
# 9         Parker
# 10        George
# 11        Potter
# 12        Draper
# 13       Houston
# 14    Richardson
# 15       Weasley
# 16         Scott
# 17          Kent
# 18        Braton
# 19     Skywalker
# Name: Last_Name, dtype: object

# %%
df['Last_Name'] = df['Last_Name'].str.strip('/._').fillna('Unknown')

# %%
df
# Out:
#     CustomerID First_name   Last_Name  Phone_Number  \
# 0         1001      FRODO     Baggins  123-545-5421
# 1         1002       ABED       Nadir  123/643/9775
# 2         1003     WALTER       White   709/909/901
# 3         1004     DWAYNE     Shurlle  123-543-2345
# 4         1005       JOHN        Snow  876|678|3469
# 5         1006        RON     Swanson  304-762-2467
# 6         1007       JEFF      Winger           NaN
# 7         1008   SHERLOCK      Holmes  876|678|3469
# 8         1009    GANDALF     Unknown           N/a
# 9         1010      PETER      Parker  123-545-5421
# 10        1011      SAMMY      George           NaN
# 11        1012      HARRY      Potter   706#695#039
# 12        1013        DON      Draper  123-543-2345
# 13        1014     LESLIE     Houston  876|678|3469
# 14        1015       TOBY  Richardson  304-762-2467
# 15        1016        RON     Weasley  123-545-5421
# 16        1017    MICHAEL       Scott  123/643/9775
# ...

# %% [markdown]
# ### Replace Method

# %%
df['Phone_Number']
# Out:
# 0     123-545-5421
# 1     123/643/9775
# 2      709/909/901
# 3     123-543-2345
# 4     876|678|3469
# 5     304-762-2467
# 6              NaN
# 7     876|678|3469
# 8              N/a
# 9     123-545-5421
# 10             NaN
# 11     706#695#039
# 12    123-543-2345
# 13    876|678|3469
# 14    304-762-2467
# 15    123-545-5421
# 16    123/643/9775
# 17     709/909/901
# 18             N/a
# 19    876|678|3469
# Name: Phone_Number, dtype: object

# %%
#remember, in Python, Nan is for NULL, N/A is different

# %%
df['Phone_Number'].str.replace('/','-')
# Out:
# 0     123-545-5421
# 1     123-643-9775
# 2      709-909-901
# 3     123-543-2345
# 4     876|678|3469
# 5     304-762-2467
# 6              NaN
# 7     876|678|3469
# 8              N-a
# 9     123-545-5421
# 10             NaN
# 11     706#695#039
# 12    123-543-2345
# 13    876|678|3469
# 14    304-762-2467
# 15    123-545-5421
# 16    123-643-9775
# 17     709-909-901
# 18             N-a
# 19    876|678|3469
# Name: Phone_Number, dtype: object

# %%
df['Phone_Number'].str.replace('[#/|]','-')
# Out:
# C:\Users\Jo$h\AppData\Local\Temp\ipykernel_6248\2287002745.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Phone_Number'].str.replace('[#/|]','-')
# 0     123-545-5421
# 1     123-643-9775
# 2      709-909-901
# 3     123-543-2345
# 4     876-678-3469
# 5     304-762-2467
# 6              NaN
# 7     876-678-3469
# 8              N-a
# 9     123-545-5421
# 10             NaN
# 11     706-695-039
# 12    123-543-2345
# 13    876-678-3469
# 14    304-762-2467
# 15    123-545-5421
# 16    123-643-9775
# 17     709-909-901
# 18             N-a
# 19    876-678-3469
# Name: Phone_Number, dtype: object

# %%
df['Phone_Number'].str.replace('[#/|]','-',regex=True)
# Out:
# 0     123-545-5421
# 1     123-643-9775
# 2      709-909-901
# 3     123-543-2345
# 4     876-678-3469
# 5     304-762-2467
# 6              NaN
# 7     876-678-3469
# 8              N-a
# 9     123-545-5421
# 10             NaN
# 11     706-695-039
# 12    123-543-2345
# 13    876-678-3469
# 14    304-762-2467
# 15    123-545-5421
# 16    123-643-9775
# 17     709-909-901
# 18             N-a
# 19    876-678-3469
# Name: Phone_Number, dtype: object

# %%
df['Phone_Number'].str.replace('[0-9]','',regex=True)   #replace anything that's 0-9 with nothing
# Out:
# 0      --
# 1      //
# 2      //
# 3      --
# 4      ||
# 5      --
# 6     NaN
# 7      ||
# 8     N/a
# 9      --
# 10    NaN
# 11     ##
# 12     --
# 13     ||
# 14     --
# 15     --
# 16     //
# 17     //
# 18    N/a
# 19     ||
# Name: Phone_Number, dtype: object

# %%
df['Phone_Number'].str.replace('[^A-za-z]','',regex=True)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5
# 6     NaN
# 7
# 8      Na
# 9
# 10    NaN
# 11
# 12
# 13
# 14
# 15
# 16
# 17
# 18     Na
# 19
# Name: Phone_Number, dtype: object

# %%
df['Phone_Number'].str.replace('[^A-za-z0-9]','',regex=True)
# Out:
# 0     1235455421
# 1     1236439775
# 2      709909901
# 3     1235432345
# 4     8766783469
# 5     3047622467
# 6            NaN
# 7     8766783469
# 8             Na
# 9     1235455421
# 10           NaN
# 11     706695039
# 12    1235432345
# 13    8766783469
# 14    3047622467
# 15    1235455421
# 16    1236439775
# 17     709909901
# 18            Na
# 19    8766783469
# Name: Phone_Number, dtype: object

# %%
df['Phone_Number'].str.replace('[^0-9]','',regex=True).fillna(0)
# Out:
# 0     1235455421
# 1     1236439775
# 2      709909901
# 3     1235432345
# 4     8766783469
# 5     3047622467
# 6              0
# 7     8766783469
# 8
# 9     1235455421
# 10             0
# 11     706695039
# 12    1235432345
# 13    8766783469
# 14    3047622467
# 15    1235455421
# 16    1236439775
# 17     709909901
# 18
# 19    8766783469
# Name: Phone_Number, dtype: object

# %%
df['Phone_Number'] = df['Phone_Number'].str.replace('[^0-9]','',regex=True).fillna(0)

# %%
df['Phone_Number']
# Out:
# 0     1235455421
# 1     1236439775
# 2      709909901
# 3     1235432345
# 4     8766783469
# 5     3047622467
# 6              0
# 7     8766783469
# 8
# 9     1235455421
# 10             0
# 11     706695039
# 12    1235432345
# 13    8766783469
# 14    3047622467
# 15    1235455421
# 16    1236439775
# 17     709909901
# 18
# 19    8766783469
# Name: Phone_Number, dtype: object

# %%
'090'+ df['Phone_Number'].astype('str')
# Out:
# 0     0901235455421
# 1     0901236439775
# 2      090709909901
# 3     0901235432345
# 4     0908766783469
# 5     0903047622467
# 6              0900
# 7     0908766783469
# 8               090
# 9     0901235455421
# 10             0900
# 11     090706695039
# 12    0901235432345
# 13    0908766783469
# 14    0903047622467
# 15    0901235455421
# 16    0901236439775
# 17     090709909901
# 18              090
# 19    0908766783469
# Name: Phone_Number, dtype: object

# %%
df['Phone_Number'] = '090'+ df['Phone_Number'].astype('str')

# %%
df
# Out:
#     CustomerID First_name   Last_Name   Phone_Number  \
# 0         1001      FRODO     Baggins  0901235455421
# 1         1002       ABED       Nadir  0901236439775
# 2         1003     WALTER       White   090709909901
# 3         1004     DWAYNE     Shurlle  0901235432345
# 4         1005       JOHN        Snow  0908766783469
# 5         1006        RON     Swanson  0903047622467
# 6         1007       JEFF      Winger           0900
# 7         1008   SHERLOCK      Holmes  0908766783469
# 8         1009    GANDALF     Unknown            090
# 9         1010      PETER      Parker  0901235455421
# 10        1011      SAMMY      George           0900
# 11        1012      HARRY      Potter   090706695039
# 12        1013        DON      Draper  0901235432345
# 13        1014     LESLIE     Houston  0908766783469
# 14        1015       TOBY  Richardson  0903047622467
# 15        1016        RON     Weasley  0901235455421
# 16        1017    MICHAEL       Scott  0901236439775
# ...

# %%
df['Paying Customer'].value_counts()
# Out:
# Yes    10
# Y       4
# No      3
# N       2
# N/a     1
# Name: Paying Customer, dtype: int64

# %%
df['Paying Customer'] = df['Paying Customer'].str.replace('Yes','Y')
df['Paying Customer'] = df['Paying Customer'].str.replace('No','N')
df['Paying Customer'] = df['Paying Customer'].str.replace('N/a','N')

# %%
df['Paying Customer'].value_counts()
# Out:
# Y    14
# N     6
# Name: Paying Customer, dtype: int64

# %%
df['Paying Customer'].loc[10] = 'S'
df['Paying Customer'].loc[5] = 'R'
# Out:
# C:\Users\Jo$h\AppData\Local\Temp\ipykernel_6248\344836549.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Paying Customer'].loc[10] = 'S'
# C:\Users\Jo$h\AppData\Local\Temp\ipykernel_6248\344836549.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Paying Customer'].loc[5] = 'R'

# %%
df['Paying Customer']
# Out:
# 0     Y
# 1     N
# 2     N
# 3     Y
# 4     Y
# 5     R
# 6     N
# 7     N
# 8     Y
# 9     Y
# 10    S
# 11    Y
# 12    Y
# 13    Y
# 14    Y
# 15    N
# 16    Y
# 17    Y
# 18    N
# 19    Y
# Name: Paying Customer, dtype: object

# %%
def sometin (value):
    if value == 'S':
        return 1
    elif value == 'Q':
        return 2
    else:
        return 3

# %%
df['test'] = df['Paying Customer'].apply(sometin)

# %%
df
# Out:
#     CustomerID First_name   Last_Name   Phone_Number  \
# 0         1001      FRODO     Baggins  0901235455421
# 1         1002       ABED       Nadir  0901236439775
# 2         1003     WALTER       White   090709909901
# 3         1004     DWAYNE     Shurlle  0901235432345
# 4         1005       JOHN        Snow  0908766783469
# 5         1006        RON     Swanson  0903047622467
# 6         1007       JEFF      Winger           0900
# 7         1008   SHERLOCK      Holmes  0908766783469
# 8         1009    GANDALF     Unknown            090
# 9         1010      PETER      Parker  0901235455421
# 10        1011      SAMMY      George           0900
# 11        1012      HARRY      Potter   090706695039
# 12        1013        DON      Draper  0901235432345
# 13        1014     LESLIE     Houston  0908766783469
# 14        1015       TOBY  Richardson  0903047622467
# 15        1016        RON     Weasley  0901235455421
# 16        1017    MICHAEL       Scott  0901236439775
# ...

# %% [markdown]
# ### Split Method

# %%
df['Address']
# Out:
# 0                     123 Shire Lane, Shire
# 1                       93 West Main Street
# 2                        298 Drugs Driveway
# 3     980 Paper Avenue, Pennsylvania, 18503
# 4                          123 Dragons Road
# 5                          768 City Parkway
# 6                         1209 South Street
# 7                             98 Clue Drive
# 8                          123 Middle Earth
# 9                25th Main Street, New York
# 10                    612 Shire Lane, Shire
# 11                     2394 Hogwarts Avenue
# 12                         2039 Main Street
# 13                         343 City Parkway
# 14                            214 HR Avenue
# 15                     2395 Hogwarts Avenue
# 16           121 Paper Avenue, Pennsylvania
# 17                          3496 Super Lane
# 18                                      N/a
# 19              910 Tatooine Road, Tatooine
# Name: Address, dtype: object

# %%
df['Address'].str.split(' ', expand = True)
# Out:
#        0         1         2              3      4
# 0    123     Shire     Lane,          Shire   None
# 1     93      West      Main         Street   None
# 2    298     Drugs  Driveway           None   None
# 3    980     Paper   Avenue,  Pennsylvania,  18503
# 4    123   Dragons      Road           None   None
# 5    768      City   Parkway           None   None
# 6   1209     South    Street           None   None
# 7     98      Clue     Drive           None   None
# 8    123    Middle     Earth           None   None
# 9   25th      Main   Street,            New   York
# 10   612     Shire     Lane,          Shire   None
# 11  2394  Hogwarts    Avenue           None   None
# 12  2039      Main    Street           None   None
# 13   343      City   Parkway           None   None
# 14   214        HR    Avenue           None   None
# 15  2395  Hogwarts    Avenue           None   None
# 16   121     Paper   Avenue,   Pennsylvania   None
# ...

# %%
df['Address'].str.split(' ', expand = True)[0]
# Out:
# 0      123
# 1       93
# 2      298
# 3      980
# 4      123
# 5      768
# 6     1209
# 7       98
# 8      123
# 9     25th
# 10     612
# 11    2394
# 12    2039
# 13     343
# 14     214
# 15    2395
# 16     121
# 17    3496
# 18     N/a
# 19     910
# Name: 0, dtype: object

# %%
df['Address'].str.split(' ', expand = True)[0].str.strip('Na/th')
# Out:
# 0      123
# 1       93
# 2      298
# 3      980
# 4      123
# 5      768
# 6     1209
# 7       98
# 8      123
# 9       25
# 10     612
# 11    2394
# 12    2039
# 13     343
# 14     214
# 15    2395
# 16     121
# 17    3496
# 18
# 19     910
# Name: 0, dtype: object

# %%
df['Address'].str.split(' ', expand = True)[0].str.replace('[^0-9]','')
# Out:
# C:\Users\Jo$h\AppData\Local\Temp\ipykernel_6248\24870064.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Address'].str.split(' ', expand = True)[0].str.replace('[^0-9]','')
# 0      123
# 1       93
# 2      298
# 3      980
# 4      123
# 5      768
# 6     1209
# 7       98
# 8      123
# 9       25
# 10     612
# 11    2394
# 12    2039
# 13     343
# 14     214
# 15    2395
# 16     121
# 17    3496
# 18
# 19     910
# Name: 0, dtype: object

# %%
df['StreetNo'] = df['Address'].str.split(' ', expand = True)[0].str.replace('[^0-9]','')
# Out:
# C:\Users\Jo$h\AppData\Local\Temp\ipykernel_6248\3367540984.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['StreetNo'] = df['Address'].str.split(' ', expand = True)[0].str.replace('[^0-9]','')

# %%
df
# Out:
#     CustomerID First_name   Last_Name   Phone_Number  \
# 0         1001      FRODO     Baggins  0901235455421
# 1         1002       ABED       Nadir  0901236439775
# 2         1003     WALTER       White   090709909901
# 3         1004     DWAYNE     Shurlle  0901235432345
# 4         1005       JOHN        Snow  0908766783469
# 5         1006        RON     Swanson  0903047622467
# 6         1007       JEFF      Winger           0900
# 7         1008   SHERLOCK      Holmes  0908766783469
# 8         1009    GANDALF     Unknown            090
# 9         1010      PETER      Parker  0901235455421
# 10        1011      SAMMY      George           0900
# 11        1012      HARRY      Potter   090706695039
# 12        1013        DON      Draper  0901235432345
# 13        1014     LESLIE     Houston  0908766783469
# 14        1015       TOBY  Richardson  0903047622467
# 15        1016        RON     Weasley  0901235455421
# 16        1017    MICHAEL       Scott  0901236439775
# ...

# %% [markdown]
# ###### splitting by ,       and also creating new columns in the process

# %%
df[['StreetName','State','ZipCode']] = df['Address'].str.split(',',expand=True)

# %%
df
# Out:
#     CustomerID First_name   Last_Name   Phone_Number  \
# 0         1001      FRODO     Baggins  0901235455421
# 1         1002       ABED       Nadir  0901236439775
# 2         1003     WALTER       White   090709909901
# 3         1004     DWAYNE     Shurlle  0901235432345
# 4         1005       JOHN        Snow  0908766783469
# 5         1006        RON     Swanson  0903047622467
# 6         1007       JEFF      Winger           0900
# 7         1008   SHERLOCK      Holmes  0908766783469
# 8         1009    GANDALF     Unknown            090
# 9         1010      PETER      Parker  0901235455421
# 10        1011      SAMMY      George           0900
# 11        1012      HARRY      Potter   090706695039
# 12        1013        DON      Draper  0901235432345
# 13        1014     LESLIE     Houston  0908766783469
# 14        1015       TOBY  Richardson  0903047622467
# 15        1016        RON     Weasley  0901235455421
# 16        1017    MICHAEL       Scott  0901236439775
# ...

# %% [markdown]
# ### DateTime

# %%
# db['DOB'].dt.year
# db['DOB'].dt.month
# db['DOB'].dt.day

# db.loc[db['DOB'].dt.year > 1997]
# db.loc[db['DOB'].dt.year > 1997].shape


# pd.Timestamp.now()
# pd.Timestamp.now().time()

# pd.Timestamp.today()
# pd.Timestamp.today().year
# pd.Timestamp.today().year - db.['DOB'].dt.year

# db['Age'] = pd.Timestamp.today().year - db.['DOB'].dt.year

# %% [markdown]
# # CONVERTING A DATAFRAME TO A DICTIONARY

# %%
df
# Out:
#     CustomerID First_name   Last_Name   Phone_Number  \
# 0         1001      FRODO     Baggins  0901235455421
# 1         1002       ABED       Nadir  0901236439775
# 2         1003     WALTER       White   090709909901
# 3         1004     DWAYNE     Shurlle  0901235432345
# 4         1005       JOHN        Snow  0908766783469
# 5         1006        RON     Swanson  0903047622467
# 6         1007       JEFF      Winger           0900
# 7         1008   SHERLOCK      Holmes  0908766783469
# 8         1009    GANDALF     Unknown            090
# 9         1010      PETER      Parker  0901235455421
# 10        1011      SAMMY      George           0900
# 11        1012      HARRY      Potter   090706695039
# 12        1013        DON      Draper  0901235432345
# 13        1014     LESLIE     Houston  0908766783469
# 14        1015       TOBY  Richardson  0903047622467
# 15        1016        RON     Weasley  0901235455421
# 16        1017    MICHAEL       Scott  0901236439775
# ...

# %%
df.to_dict()
# Out:
# {'CustomerID': {0: 1001,
#   1: 1002,
#   2: 1003,
#   3: 1004,
#   4: 1005,
#   5: 1006,
#   6: 1007,
#   7: 1008,
#   8: 1009,
#   9: 1010,
#   10: 1011,
#   11: 1012,
#   12: 1013,
#   13: 1014,
#   14: 1015,
#   15: 1016,
#   16: 1017,
#   17: 1018,
#   18: 1019,
#   19: 1020},
#  'First_name': {0: 'FRODO',
#   1: 'ABED',
#   2: 'WALTER',
#   3: 'DWAYNE',
#   4: 'JOHN',
#   5: 'RON',
#   6: 'JEFF',
#   7: 'SHERLOCK',
#   8: 'GANDALF',
#   9: 'PETER',
#   10: 'SAMMY',
#   11: 'HARRY',
#   12: 'DON',
#   13: 'LESLIE',
#   14: 'TOBY',
#   15: 'RON',
#   16: 'MICHAEL',
#   17: 'CLARK',
#   18: 'CREED',
#   19: 'ANAKIN'},
#  'Last_Name': {0: 'Baggins',
#   1: 'Nadir',
#   2: 'White',
#   3: 'Shurlle',
#   4: 'Snow',
#   5: 'Swanson',
#   6: 'Winger',
#   7: 'Holmes',
#   8: 'Unknown',
#   9: 'Parker',
#   10: 'George',
#   11: 'Potter',
#   12: 'Draper',
#   13: 'Houston',
#   14: 'Richardson',
#   15: 'Weasley',
#   16: 'Scott',
#   17: 'Kent',
#   18: 'Braton',
# ...

# %%
#this allows you to also manipultate the data and easily add another row
